# %%
from tkinter import *
from pygame import mixer
import random



m=Tk()

m.geometry("1920x1080")


l=700
'''
def increment():
    global l
    l=l+100
def decrement():
    global l
    l=l-100


f3=Frame(m,bg="pink",borderwidth=5,relief="sunken")
f3.pack(side="right")
Label(f3,text="change size of LUDO").pack()
Button(f3,text="Increase by 10",command=increment).pack(side="top")
Button(f3,text="Decrease by 10",command=decrement).pack(side="top")
'''

z=l/2
w=Canvas(m,width=l,height=l,bg="pink")
j=6*l/15
k=9*l/15
rect1=w.create_rectangle(0,0,j,j,fill="blue")
rect3=w.create_rectangle(0,k,j,l,fill="red")
rect7=w.create_rectangle(k,0,l,j,fill="yellow")
rect9=w.create_rectangle(k,k,l,l,fill="green")


triangle1=w.create_polygon(j,j,j,k,z,z,fill="blue")
triangle2=w.create_polygon(j,k,z,z,k,k,fill="red")
triangle3=w.create_polygon(j,j,z,z,k,j,fill="yellow")
triangle4=w.create_polygon(z,z,k,j,k,k,fill="green")


a=l/15
b=2*a
c=3*a
d=4*a
e=5*a

p=7*a
q=8*a

r=10*a
s=11*a
t=12*a
u=13*a
v=14*a



# 1.small boxes between blue and red
rect_br1=w.create_rectangle(0,j,a,p,fill="white")
rect_br2=w.create_rectangle(a,j,b,p,fill="blue")
rect_br3=w.create_rectangle(b,j,c,p,fill="white")
rect_br4=w.create_rectangle(c,j,d,p,fill="white")
rect_br5=w.create_rectangle(d,j,e,p,fill="white")
rect_br6=w.create_rectangle(e,j,j,p,fill="white")

rect_br7=w.create_rectangle(0,p,a,q,fill="white")
rect_br8=w.create_rectangle(a,p,b,q,fill="blue")
rect_br9=w.create_rectangle(b,p,c,q,fill="blue")
rect_br10=w.create_rectangle(c,p,d,q,fill="blue")
rect_br11=w.create_rectangle(d,p,e,q,fill="blue")
rect_br12=w.create_rectangle(e,p,j,q,fill="blue")

rect_br13=w.create_rectangle(0,q,a,k,fill="white")
rect_br14=w.create_rectangle(a,q,b,k,fill="white")
rect_br15=w.create_rectangle(b,q,c,k,fill="white")
rect_br16=w.create_rectangle(c,q,d,k,fill="white")
rect_br17=w.create_rectangle(d,q,e,k,fill="white")
rect_br18=w.create_rectangle(e,q,j,k,fill="white")

#2. small boxes between blue and yellow
rect_by1=w.create_rectangle(j,0,p,a,fill="white")
rect_by1=w.create_rectangle(j,a,p,b,fill="white")
rect_by1=w.create_rectangle(j,b,p,c,fill="white")
rect_by1=w.create_rectangle(j,c,p,d,fill="white")
rect_by1=w.create_rectangle(j,d,p,e,fill="white")
rect_by1=w.create_rectangle(j,e,p,j,fill="white")

rect_by1=w.create_rectangle(p,0,q,a,fill="white")
rect_by1=w.create_rectangle(p,a,q,b,fill="yellow")
rect_by1=w.create_rectangle(p,b,q,c,fill="yellow")
rect_by1=w.create_rectangle(p,c,q,d,fill="yellow")
rect_by1=w.create_rectangle(p,d,q,e,fill="yellow")
rect_by1=w.create_rectangle(p,e,q,j,fill="yellow")

rect_by1=w.create_rectangle(q,0,k,a,fill="white")
rect_by1=w.create_rectangle(q,a,k,b,fill="yellow")
rect_by1=w.create_rectangle(q,b,k,c,fill="white")
rect_by1=w.create_rectangle(q,c,k,d,fill="white")
rect_by1=w.create_rectangle(q,d,k,e,fill="white")
rect_by1=w.create_rectangle(q,e,k,j,fill="white")


#3.small boxes between red and green

rect_by1=w.create_rectangle(j,k,p,r,fill="white")
rect_by1=w.create_rectangle(j,r,p,s,fill="white")
rect_by1=w.create_rectangle(j,s,p,t,fill="white")
rect_by1=w.create_rectangle(j,t,p,u,fill="white")
rect_by1=w.create_rectangle(j,u,p,v,fill="red")
rect_by1=w.create_rectangle(j,v,p,l,fill="white")

rect_by1=w.create_rectangle(p,k,q,r,fill="red")
rect_by1=w.create_rectangle(p,r,q,s,fill="red")
rect_by1=w.create_rectangle(p,s,q,t,fill="red")
rect_by1=w.create_rectangle(p,t,q,u,fill="red")
rect_by1=w.create_rectangle(p,u,q,v,fill="red")
rect_by1=w.create_rectangle(p,v,q,l,fill="white")

rect_by1=w.create_rectangle(q,k,k,r,fill="white")
rect_by1=w.create_rectangle(q,r,k,s,fill="white")
rect_by1=w.create_rectangle(q,s,k,t,fill="white")
rect_by1=w.create_rectangle(q,t,k,u,fill="white")
rect_by1=w.create_rectangle(q,u,k,v,fill="white")
rect_by1=w.create_rectangle(q,v,k,l,fill="white")

#4.small boxes between green and yellow

rect_gy1=w.create_rectangle(k,j,r,p,fill="white")
rect_gy2=w.create_rectangle(r,j,s,p,fill="white")
rect_gy3=w.create_rectangle(s,j,t,p,fill="white")
rect_gy4=w.create_rectangle(t,j,u,p,fill="white")
rect_gy5=w.create_rectangle(u,j,v,p,fill="white")
rect_gy6=w.create_rectangle(v,j,l,p,fill="white")

rect_gy7=w.create_rectangle(k,p,r,q,fill="green")
rect_gy8=w.create_rectangle(r,p,s,q,fill="green")
rect_gy9=w.create_rectangle(s,p,t,q,fill="green")
rect_gy10=w.create_rectangle(t,p,u,q,fill="green")
rect_gy11=w.create_rectangle(u,p,v,q,fill="green")
rect_gy12=w.create_rectangle(v,p,l,q,fill="white")

rect_gy13=w.create_rectangle(k,q,r,k,fill="white")
rect_gy14=w.create_rectangle(r,q,s,k,fill="white")
rect_gy15=w.create_rectangle(s,q,t,k,fill="white")
rect_gy16=w.create_rectangle(t,q,u,k,fill="white")
rect_gy17=w.create_rectangle(u,q,v,k,fill="green")
rect_gy18=w.create_rectangle(v,q,l,k,fill="white")

#rect for inside buttons
rect_ib1=w.create_rectangle(a,a,e,e,fill="light blue")
rect_ir1=w.create_rectangle(a,r,e,v,fill="pink")
rect_ig1=w.create_rectangle(r,r,v,v,fill="light green")
rect_iy1=w.create_rectangle(r,a,v,e,fill="light yellow")

#circle inside blue rectangle
cir_ib1=w.create_oval((a+b)/2,(a+b)/2,((b+c)/2)-10,((b+c)/2)-10,fill="blue")
cir_ib2=w.create_oval((a+b)/2,(c+d)/2,((b+c)/2)-10,((d+e)/2)-10,fill="blue")
cir_ib3=w.create_oval((c+d)/2,(a+b)/2,((d+e)/2)-10,((b+c)/2)-10,fill="blue")
cir_ib4=w.create_oval((c+d)/2,(c+d)/2,((d+e)/2)-10,((d+e)/2)-10,fill="blue")

#circle inside red rectangle#
cir_ir1=w.create_oval((a+b)/2,((r+s)/2)+10,((b+c)/2)-10,(s+t)/2,fill="red")
cir_ir2=w.create_oval((a+b)/2,((t+u)/2)+10,((b+c)/2)-10,(u+v)/2,fill="red")
cir_ir3=w.create_oval((c+d)/2,((r+s)/2)+10,((d+e)/2)-10,(s+t)/2,fill="red")
cir_ir4=w.create_oval((c+d)/2,((t+u)/2)+10,((d+e)/2)-10,(u+v)/2,fill="red")

#circle inside yellow rectangle
cir_iy1=w.create_oval(((r+s)/2)+10,(a+b)/2,(s+t)/2,((b+c)/2)-10,fill="yellow")
cir_iy2=w.create_oval(((t+u)/2)+10,(a+b)/2,(u+v)/2,((b+c)/2)-10,fill="yellow")
cir_iy3=w.create_oval(((r+s)/2)+10,(c+d)/2,(s+t)/2,((d+e)/2)-10,fill="yellow")
cir_iy4=w.create_oval(((t+u)/2)+10,(c+d)/2,(u+v)/2,((d+e)/2)-10,fill="yellow")

#circle inside green rectangle
cir_ig1=w.create_oval(((r+s)/2)+10,((r+s)/2)+10,(s+t)/2,(s+t)/2,fill="green")
cir_ig2=w.create_oval(((r+s)/2)+10,((t+u)/2)+10,(s+t)/2,(u+v)/2,fill="green")
cir_ig3=w.create_oval(((t+u)/2)+10,((r+s)/2)+10,(u+v)/2,(s+t)/2,fill="green")
cir_ig4=w.create_oval(((t+u)/2)+10,((t+u)/2)+10,(u+v)/2,(u+v)/2,fill="green")



# start as star

#triangle1=w.create_polygon(j,j,j,k,z,z,fill="blue")

#start_b=w.create_polygon()


f1=Frame(m,bg="blue",borderwidth=5,relief="sunken")
Label(f1,text="lets play LUDO with python",font="calibry 20 bold" ,bg="red",padx=700).pack(side="left",fill=X)
f1.pack(side="top",fill=X)






w.pack(side=RIGHT,padx=25,pady=15)



#formation of dice

center=w.create_rectangle(p+1,p+1,q+1,q+1,fill="pink")
toss=0



#Label(m,text="PLAY",font="calibri 20 bold").pack(side="bottom")




def call(colo):
    global center,toss,dot,l0
    toss=random.randint(1,6)
    if toss==1:
        #number 1
       
       # w.delete(center)
        center=w.create_rectangle(p,p,q,q,fill=colo)
   
        d4=w.create_oval(p+(3*l/120),p+(4*l/120),p+(4*l/120),p+(5*l/120),fill="black")
    if toss==2:
       
       
        #number 2
        #w.delete(center)
        center=w.create_rectangle(p,p,q,q,fill=colo)
       
       
        d2=w.create_oval(p+(3*l/120),p+(2*l/120),p+(4*l/120),p+(3*l/120),fill="black")
        d6=w.create_oval(p+(3*l/120),p+(6*l/120),p+(4*l/120),p+(7*l/120),fill="black")
    if toss==3:
       
        #w.delete(center)
        center=w.create_rectangle(p,p,q,q,fill=colo)
       
       
        d3=w.create_oval(p+(5*l/120),p+(2*l/120),p+(6*l/120),p+(3*l/120),fill="black")

        d4=w.create_oval(p+(3*l/120),p+(4*l/120),p+(4*l/120),p+(5*l/120),fill="black")

        d5=w.create_oval(p+(1*l/120),p+(6*l/120),p+(2*l/120),p+(7*l/120),fill="black")
       
    if toss==4:
       
        #number 4
       # w.delete(center)
        center=w.create_rectangle(p,p,q,q,fill=colo)
       
       
        d1=w.create_oval(p+(1*l/120),p+(2*l/120),p+(2*l/120),p+(3*l/120),fill="black")
        d3=w.create_oval(p+(5*l/120),p+(2*l/120),p+(6*l/120),p+(3*l/120),fill="black")
       
        d5=w.create_oval(p+(1*l/120),p+(6*l/120),p+(2*l/120),p+(7*l/120),fill="black")
        d7=w.create_oval(p+(5*l/120),p+(6*l/120),p+(6*l/120),p+(7*l/120),fill="black")
    if toss==5:
       
        #number 5
        #w.delete(center)
        center=w.create_rectangle(p,p,q,q,fill=colo)
       
       
        d1=w.create_oval(p+(1*l/120),p+(2*l/120),p+(2*l/120),p+(3*l/120),fill="black")
        d3=w.create_oval(p+(5*l/120),p+(2*l/120),p+(6*l/120),p+(3*l/120),fill="black")

        d4=w.create_oval(p+(3*l/120),p+(4*l/120),p+(4*l/120),p+(5*l/120),fill="black")


        d5=w.create_oval(p+(1*l/120),p+(6*l/120),p+(2*l/120),p+(7*l/120),fill="black")
        d7=w.create_oval(p+(5*l/120),p+(6*l/120),p+(6*l/120),p+(7*l/120),fill="black")
    if toss==6:
       
        #number 6
        #w.delete(center)
       
       
       
       
       
       
        d1=w.create_oval(p+(1*l/120),p+(2*l/120),p+(2*l/120),p+(3*l/120),fill="black")
        d2=w.create_oval(p+(3*l/120),p+(2*l/120),p+(4*l/120),p+(3*l/120),fill="black")
        d3=w.create_oval(p+(5*l/120),p+(2*l/120),p+(6*l/120),p+(3*l/120),fill="black")

        d4=w.create_oval(p+(1*l/120),p+(6*l/120),p+(2*l/120),p+(7*l/120),fill="black")
        d5=w.create_oval(p+(3*l/120),p+(6*l/120),p+(4*l/120),p+(7*l/120),fill="black")
        d6=w.create_oval(p+(5*l/120),p+(6*l/120),p+(6*l/120),p+(7*l/120),fill="black")
       
q11=[1,2,3,4]
r11=q11[0]
p11=1

move_blue,move_red,move_yellow,move_green=0,0,0,0


def click():
    global center,p11,toss,q11,r11,move_blue,move_red,move_yellow,move_green
   
    if (r11==q11[0]):
        move_blue=1
        move_red,move_yellow,move_green=0,0,0
       
        center=w.create_rectangle(p,p,q,q,fill="blue")
        call("blue")
        #move_item("blue")
       
        if toss!=6:
            r11=q11[1]
       
        return 0
       
    if (r11==q11[1]):
        move_red=1
        move_blue,move_yellow,move_green=0,0,0
       
        center=w.create_rectangle(p,p,q,q,fill="red")
        call("red")
        #move_item("red")
       
        if toss!=6:
            r11=q11[2]
       
        return 0
       
    if  (r11==q11[2]):
        move_green=1
        move_red,move_yellow,move_blue=0,0,0
       
        center=w.create_rectangle(p,p,q,q,fill="green")
        call("green")
        #move_item("green")
       
        if toss!=6:
            r11=q11[3]
               
        return 0
       
    if (r11==q11[3]):
        move_yellow=1
        move_red,move_blue,move_green=0,0,0
       
        center=w.create_rectangle(p,p,q,q,fill="yellow")
        call("yellow")
        #move_item("green")
       
        if toss!=6:
            r11=q11[0]
       
        return 0
   
   
Button(m,text="ROLL DIE!",font="calibri 18 bold",bg="plum",padx=20,pady=20,command=click).pack(side="right",anchor="e")





#def name():
#    Label(m,text="",font="calibri 50 bold").pack()
#def name2():
 #   img=Image.open(r"C:\Users\VISERION\Desktop\vik_passport.jpg")
  #  img=img.resize((100,100),Image.ANTIALIAS)
   # photo=ImageTk.PhotoImage(img)
    #Label(image=photo).pack(side="bottom")
#mymenu=Menu(m)
#mymenu.add_command(label="vikash",command=name,background="red")
#mymenu.add_command(label="kumar",command=name2)

#m.config(menu=mymenu)



z1=l/30
a1,b1,c1,d1,e1,j1,p1,q1,k1,r1,s1,t1,u1,v1,l1 = z1,a+z1,b+z1,c+z1,d+z1,e+z1,j+z1,p+z1,q+z1,k+z1,r+z1,s+z1,t+z1,u+z1,v+z1






redx=[0,p1,p1,p1,p1,p1,j1,e1,d1,c1,b1,a1,a1,a1,b1,c1,d1,e1,j1,p1,p1,p1,p1,p1,p1,q1,k1,k1,k1,k1,k1,k1,r1,s1,t1,u1,v1,l1,l1,l1,v1,u1,t1,s1,r1,k1,k1,k1,k1,k1,k1,q1,q1,q1,q1,q1,q1,q1]
redy=[0,v1,u1,t1,s1,r1,k1,k1,k1,k1,k1,k1,q1,p1,p1,p1,p1,p1,p1,j1,e1,d1,c1,b1,a1,a1,a1,b1,c1,d1,e1,j1,p1,p1,p1,p1,p1,p1,q1,k1,k1,k1,k1,k1,k1,r1,s1,t1,u1,v1,l1,l1,v1,u1,t1,s1,r1,k1]


       
   
   
rx_1,ry_1=0,0
rxp1,ryp1=0,0

def x1(event):
    global redx,rx_1,p1,v1,rxp1,ryp1,move_red
    global redy,ry_1,toss
    #toss1=toss

    if(move_red==1):
       
        if toss==6 and rx_1==0:
            p2=p1-b
            q2=v1-s
            w.move(cir_ir1,p2,q2)
            rx_1=1
            ry_1=1
           
            move_red=0    
            return
           
        if rx_1>=1:
           
            rxp1=rx_1
            ryp1=ry_1
           
            if(rx_1+toss<=57 and ry_1+toss<=57):
                rx_1=rx_1+(toss)
                ry_1=ry_1+(toss)
               
               
            p2=redx[rx_1]-redx[rxp1]
            q2=redy[ry_1]-redy[ryp1]
                   
            w.move(cir_ir1,p2,q2)
           
            move_red=0    
            return


   
   

rx_2,ry_2=0,0
rxp2,ryp2=0,0

def x2(event):
    global redx,rx_2,p1,v1,rxp2,ryp2,move_red
    global redy,ry_2,toss
   
    #toss2=toss
    if(move_red==1):
       
        if toss==6 and rx_2==0:
            p2=p1-b
            q2=v1-u
            w.move(cir_ir2,p2,q2)
            rx_2=1
            ry_2=1
           
            move_red=0    
            return
           
        if rx_2>=1:
            rxp2=rx_2
            ryp2=ry_2
           
           
            if(rx_2+toss<=57 and ry_2+toss<=57):
                rx_2=rx_2+(toss)
                ry_2=ry_2+(toss)
           
       
            p2=redx[rx_2]-redx[rxp2]
            q2=redy[ry_2]-redy[ryp2]
                   
            w.move(cir_ir2,p2,q2)
           
           
            move_red=0    
            return
   
rx_3,ry_3=0,0
rxp3,ryp3=0,0

def x3(event):
    global redx,rx_3,p1,v1,rxp3,ryp3,move_red
    global redy,ry_3,toss
   
    #toss3=toss
   
    if(move_red==1):
       
        if toss==6 and rx_3==0:
            p2=p1-d
            q2=v1-s
            w.move(cir_ir3,p2,q2)
            rx_3=1
            ry_3=1
           
            move_red=0    
            return
           
        if rx_3>=1:
            rxp3=rx_3
            ryp3=ry_3
           
            if(rx_3+toss<=57 and ry_3+toss<=57):
                rx_3=rx_3+(toss)
                ry_3=ry_3+(toss)
           
           
            p2=redx[rx_3]-redx[rxp3]
            q2=redy[ry_3]-redy[ryp3]
            w.move(cir_ir3,p2,q2)
       
       
            move_red=0
            return

rx_4,ry_4=0,0
rxp4,ryp4=0,0

def x4(event):
    global redx,rx_4,p1,v1,rxp4,ryp4,move_red
    global redy,ry_4,toss
    #toss4=toss
   

    if(move_red==1):
       
        if toss==6 and rx_4==0:
            p2=p1-d
            q2=v1-u
            w.move(cir_ir4,p2,q2)
            rx_4=1
            ry_4=1
           
            move_red=0    
            return
           
        if rx_4>=1:
            rxp4=rx_4
            ryp4=ry_4
           
           
            if(rx_4+toss<=57 and ry_4+toss<=57):
                rx_4=rx_4+(toss)
                ry_4=ry_4+(toss)
           
            p2=redx[rx_4]-redx[rxp4]
            q2=redy[ry_4]-redy[ryp4]
                   
            w.move(cir_ir4,p2,q2)
           
           
            move_red=0
            return
   



w.tag_bind(cir_ir2,"<Button-1>",x2)
w.tag_bind(cir_ir3,"<Button-1>",x3)
w.tag_bind(cir_ir4,"<Button-1>",x4)
w.tag_bind(cir_ir1,"<Button-1>",x1)




greenx=[0,v1,u1,t1,s1,r1,k1,k1,k1,k1,k1,k1,q1,p1,p1,p1,p1,p1,p1,j1,e1,d1,c1,b1,a1,a1,a1,b1,c1,d1,e1,j1,p1,p1,p1,p1,p1,p1,q1,k1,k1,k1,k1,k1,k1,r1,s1,t1,u1,v1,l1,l1,v1,u1,t1,s1,r1,k1]
greeny=[0,k1,k1,k1,k1,k1,r1,s1,t1,u1,v1,l1,l1,l1,v1,u1,t1,s1,r1,k1,k1,k1,k1,k1,k1,q1,p1,p1,p1,p1,p1,p1,j1,e1,d1,c1,b1,a1,a1,a1,b1,c1,d1,e1,j1,p1,p1,p1,p1,p1,p1,q1,q1,q1,q1,q1,q1,q1]



gx_1,gy_1=0,0
gxp1,gyp1=0,0

def xg1(event):
    global greenx,gx_1,k1,v1,gxp1,gyp1,move_green
    global greeny,gy_1,toss
   
   
    if(move_green==1):
        if toss==6 and gx_1==0:
            p2=v1-s
            q2=k1-s
   
            w.move(cir_ig1,p2,q2)
            gx_1=1
            gy_1=1
           
            move_green=0    
            return
   
        if gx_1>=1:
            gxp1=gx_1
            gyp1=gy_1
           
            if(gx_1+toss<=57 and gy_1+toss<=57):
                gx_1=gx_1+(toss)
                gy_1=gy_1+(toss)
           
            p2=greenx[gx_1]-greenx[gxp1]
            q2=greeny[gy_1]-greeny[gyp1]
                   
            w.move(cir_ig1,p2,q2)
           
           
            move_green=0    
            return


gx_2,gy_2=0,0
gxp2,gyp2=0,0

def xg2(event):
    global greenx,gx_2,v1,k1,gxp2,gyp2,move_green
    global greeny,gy_2,toss
   
   
    if(move_green==1):
       
        if toss==6 and gx_2==0:
            p2=v1-s
            q2=k1-u
            w.move(cir_ig2,p2,q2)
            gx_2=1
            gy_2=1
           
            move_green=0    
            return
       
        if gx_2>=1:
            gxp2=gx_2
            gyp2=gy_2
           
            if(gx_2+toss<=57 and gy_2+toss<=57):
                gx_2=gx_2+(toss)
                gy_2=gy_2+(toss)
               
            p2=greenx[gx_2]-greenx[gxp2]
            q2=greeny[gy_2]-greeny[gyp2]
           
            w.move(cir_ig2,p2,q2)
       
       
            move_green=0
            return
   
   
gx_3,gy_3=0,0
gxp3,gyp3=0,0

def xg3(event):
    global greenx,gx_3,v1,k1,gxp3,gyp3,move_green
    global greeny,gy_3,toss
   
   
    if(move_green==1):
       
        if toss==6 and gx_3==0:
            p2=v1-u
            q2=k1-s
            w.move(cir_ig3,p2,q2)
            gx_3=1
            gy_3=1
           
            move_green=0    
            return
   
        if gx_3>=1:
            gxp3=gx_3
            gyp3=gy_3
           
            if(gx_3+toss<=57 and gy_3+toss<=57):
                gx_3=gx_3+(toss)
                gy_3=gy_3+(toss)
               
            p2=greenx[gx_3]-greenx[gxp3]
            q2=greeny[gy_3]-greeny[gyp3]
           
            w.move(cir_ig3,p2,q2)
           
           
            move_green=0    
            return
   
   
gx_4,gy_4=0,0
gxp4,gyp4=0,0

def xg4(event):
    global greenx,gx_4,k1,v1,gxp4,gyp4,move_green
    global greeny,gy_4,toss
   
    if(move_green==1):
       
        if toss==6 and gx_4==0:
            p2=v1-u
            q2=k1-u
            w.move(cir_ig4,p2,q2)
            gx_4=1
            gy_4=1
           
            move_green=0    
            return
       
        if gx_4>=1:
            gxp4=gx_4
            gyp4=gy_4
           
            if(gx_4+toss<=57 and gy_4+toss<=57):
                gx_4=gx_4+(toss)
                gy_4=gy_4+(toss)
            p2=greenx[gx_4]-greenx[gxp4]
            q2=greeny[gy_4]-greeny[gyp4]
            print(p2,q2)
            w.move(cir_ig4,p2,q2)
           
           
            move_green=0
            return
   

w.tag_bind(cir_ig2,"<Button-1>",xg2)
w.tag_bind(cir_ig3,"<Button-1>",xg3)
w.tag_bind(cir_ig4,"<Button-1>",xg4)
w.tag_bind(cir_ig1,"<Button-1>",xg1)


yellowx=[0,k1,k1,k1,k1,k1,r1,s1,t1,u1,v1,l1,l1,l1,v1,u1,t1,s1,r1,k1,k1,k1,k1,k1,k1,q1,p1,p1,p1,p1,p1,p1,j1,e1,d1,c1,b1,a1,a1,a1,b1,c1,d1,e1,j1,p1,p1,p1,p1,p1,p1,q1,q1,q1,q1,q1,q1,q1]
yellowy=[0,b1,c1,d1,e1,j1,p1,p1,p1,p1,p1,p1,q1,k1,k1,k1,k1,k1,k1,r1,s1,t1,u1,v1,l1,l1,l1,v1,u1,t1,s1,r1,k1,k1,k1,k1,k1,k1,q1,p1,p1,p1,p1,p1,p1,j1,e1,d1,c1,b1,a1,a1,b1,c1,d1,e1,j1,p1]



yx_1,yy_1=0,0
yxp1,yyp1=0,0

def xy1(event):
    global yellowx,yx_1,k1,b1,yxp1,yyp1,move_yellow
    global yellowy,yy_1,toss
   
    if(move_yellow==1):
       
        if toss==6 and yx_1==0:
            p2=k1-s
            q2=b1-b
            w.move(cir_iy1,p2,q2)
            yx_1=1
            yy_1=1
           
            move_yellow=0    
            return

        if yx_1>=1:
            yxp1=yx_1
            yyp1=yy_1
           
            if(yx_1+toss<=57 and yy_1+toss<=57):
                yx_1=yx_1+(toss)
                yy_1=yy_1+(toss)
           
            p2=yellowx[yx_1]-yellowx[yxp1]
            q2=yellowy[yy_1]-yellowy[yyp1]
                   
            w.move(cir_iy1,p2,q2)
           
       
            move_yellow=0
            return


yx_2,yy_2=0,0
yxp2,yyp2=0,0
def xy2(event):
    global yellowx,yx_2,b1,k1,yxp2,yyp2,move_yellow
    global yellowy,yy_2,toss
   
   
    if(move_yellow==1):
       
        if toss==6 and yx_2==0:
            p2=k1-u
            q2=b1-b
            w.move(cir_iy2,p2,q2)
            yx_2=1
            yy_2=1
           
            move_yellow=0    
            return
       
        if yx_2>=1:
            yxp2=yx_2
            yyp2=yy_2
           
            if(yx_2+toss<=57 and yy_2+toss<=57):
                yx_2=yx_2+(toss)
                yy_2=yy_2+(toss)
            p2=yellowx[yx_2]-yellowx[yxp2]
            q2=yellowy[yy_2]-yellowy[yyp2]
           
            w.move(cir_iy2,p2,q2)
           
           
            move_yellow=0    
            return
   
yx_3,yy_3=0,0
yxp3,yyp3=0,0
def xy3(event):
    global yellowx,yx_3,b1,k1,yxp3,yyp3,move_yellow
    global yellowy,yy_3,toss
   
   
    if(move_yellow==1):
       
        if toss==6 and yx_3==0:
            p2=k1-s
            q2=b1-d
            w.move(cir_iy3,p2,q2)
            yx_3=1
            yy_3=1
           
            move_yellow=0    
            return

        if yx_3>=1:
            yxp3=yx_3
            yyp3=yy_3
           
            if(yx_3+toss<=57 and yy_3+toss<=57):
                yx_3=yx_3+(toss)
                yy_3=yy_3+(toss)
               
            p2=yellowx[yx_3]-yellowx[yxp3]
            q2=yellowy[yy_3]-yellowy[yyp3]      
            w.move(cir_iy3,p2,q2)
           
           
            move_yellow=0    
            return
       
       
yx_4,yy_4=0,0
yxp4,yyp4=0,0
def xy4(event):
    global yellowx,yx_4,k1,b1,yxp4,yyp4,move_yellow
    global yellowy,yy_4,toss
   
   
    if(move_yellow==1):
       
        if toss==6 and yx_4==0:
            p2=k1-u
            q2=b1-d
            w.move(cir_iy4,p2,q2)
            yx_4=1
            yy_4=1
           
            move_yellow=0    
            return

        if yx_4>=1:
            yxp4=yx_4
            yyp4=yy_4
           
            if(yx_4+toss<=57 and yy_4+toss<=57):
                yx_4=yx_4+(toss)
                yy_4=yy_4+(toss)
            p2=yellowx[yx_4]-yellowx[yxp4]
            q2=yellowy[yy_4]-yellowy[yyp4]
       
            w.move(cir_iy4,p2,q2)
           
           
            move_yellow=0    
            return
   

w.tag_bind(cir_iy2,"<Button-1>",xy2)
w.tag_bind(cir_iy3,"<Button-1>",xy3)
w.tag_bind(cir_iy4,"<Button-1>",xy4)
w.tag_bind(cir_iy1,"<Button-1>",xy1)



bluex=[0,b1,c1,d1,e1,j1,p1,p1,p1,p1,p1,p1,q1,k1,k1,k1,k1,k1,k1,r1,s1,t1,u1,v1,l1,l1,l1,v1,u1,t1,s1,r1,k1,k1,k1,k1,k1,k1,q1,p1,p1,p1,p1,p1,p1,j1,e1,d1,c1,b1,a1,a1,b1,c1,d1,e1,j1,p1]
bluey=[0,p1,p1,p1,p1,p1,j1,e1,d1,c1,b1,a1,a1,a1,b1,c1,d1,e1,j1,p1,p1,p1,p1,p1,p1,q1,k1,k1,k1,k1,k1,k1,r1,s1,t1,u1,v1,l1,l1,l1,v1,u1,t1,s1,r1,k1,k1,k1,k1,k1,k1,q1,q1,q1,q1,q1,q1,q1]




bx_1,by_1=0,0
bxp1,byp1=0,0

def xb1(event):
    global bluex,bx_1,p1,b1,bxp1,byp1,move_blue
    global bluey,by_1,toss
   
   
    if(move_blue==1):
       
        if toss==6 and bx_1==0:
            p2=b1-b
            q2=p1-b
            w.move(cir_ib1,p2,q2)
            bx_1=1
            by_1=1
           
            move_blue=0    
            return
   
        if bx_1>=1:
            bxp1=bx_1
            byp1=by_1
           
            if(bx_1+toss<=57 and by_1+toss<=57):
                bx_1=bx_1+(toss)
                by_1=by_1+(toss)
           
            p2=bluex[bx_1]-bluex[bxp1]
            q2=bluey[by_1]-bluey[byp1]
                   
            w.move(cir_ib1,p2,q2)
           
       
            move_blue=0
            return


bx_2,by_2=0,0
bxp2,byp2=0,0

def xb2(event):
    global bluex,bx_2,b1,p1,bxp2,byp2,move_blue
    global bluey,by_2,toss
   
   
    if(move_blue==1):
       
        if toss==6 and bx_2==0:
            p2=b1-b
            q2=p1-d
            w.move(cir_ib2,p2,q2)
            bx_2=1
            by_2=1
           
            move_blue=0    
            return
       
        if bx_2>=1:
            bxp2=bx_2
            byp2=by_2
           
           
            if(bx_2+toss<=57 and by_2+toss<=57):
                bx_2=bx_2+(toss)
                by_2=by_2+(toss)
            p2=bluex[bx_2]-bluex[bxp2]
            q2=bluey[by_2]-bluey[byp2]
           
            w.move(cir_ib2,p2,q2)
           
           
            move_blue=0    
            return
   
   
bx_3,by_3=0,0
bxp3,byp3=0,0

def xb3(event):
    global bluex,bx_3,b1,p1,bxp3,byp3,move_blue
    global bluey,by_3,toss
   
    if(move_blue==1):
         
        if toss==6 and bx_3==0:
            p2=b1-d
            q2=p1-b
            w.move(cir_ib3,p2,q2)
            bx_3=1
            by_3=1
           
            move_blue=0    
            return

        if bx_3>=1:
            bxp3=bx_3
            byp3=by_3
           
            if(bx_3+toss<=57 and by_3+toss<=57):
                bx_3=bx_3+(toss)
                by_3=by_3+(toss)
            p2=bluex[bx_3]-bluex[bxp3]
            q2=bluey[by_3]-bluey[byp3]      
            w.move(cir_ib3,p2,q2)
           
           
            move_blue=0    
            return
   
   
bx_4,by_4=0,0
bxp4,byp4=0,0

def xb4(event):
    global bluex,bx_4,p1,b1,bxp4,byp4,move_blue
    global bluey,by_4,toss
   
    if(move_blue==1):
       
        if toss==6 and bx_4==0:
            p2=b1-d
            q2=p1-d 
            w.move(cir_ib4,p2,q2)
            bx_4=1
            by_4=1
           
            move_blue=0    
            return
           
        if bx_4>=1:
            bxp4=bx_4
            byp4=by_4
           
           
            if(bx_4+toss<=57 and by_4+toss<=57):
                bx_4=bx_4+(toss)
                by_4=by_4+(toss)
            p2=bluex[bx_4]-bluex[bxp4]
            q2=bluey[by_4]-bluey[byp4]
            print(p2,q2)
            w.move(cir_ib4,p2,q2)      
           
            move_blue=0    
            return
           
       
   

   
w.tag_bind(cir_ib2,"<Button-1>",xb2)
w.tag_bind(cir_ib3,"<Button-1>",xb3)
w.tag_bind(cir_ib4,"<Button-1>",xb4)
w.tag_bind(cir_ib1,"<Button-1>",xb1)





#music

mixer.init()  


f2=Frame(m,bg="pink",borderwidth=5,relief="sunken")
f2.pack(side="left",fill=Y)

text= Label(f2,text="Rock n Roll",font="calibri 20 bold")
text.pack(fill=X)

def loadMusic():
    mixer.music.load(r"E:\Music files\ENGLISH music\Alan Walker - Faded (320 kbps).mp3")
    mixer.music.play()
def stopmusic():
    mixer.music.stop()
def pausemusic():
    mixer.music.pause()
def resumemusic():
    mixer.music.unpause()

     
playbtn= Button(f2,text="PLAY",command=loadMusic,padx=70,pady=75,bg="cyan",font="Verdana 10 ")
playbtn.pack(side="top",fill=X)
Button(f2,text="PAUSE",command=pausemusic,padx=70,pady=75,bg="mistyrose",font="Verdana 10 ").pack(side="top",fill=X)
Button(f2,text="RESUME",command=resumemusic,padx=70,pady=75,bg="lime",font="Verdana 10 ").pack(side="top",fill=X)
Button(f2,text="CLOSE",command=stopmusic,padx=70,pady=75,bg="magenta",font="Verdana 10 ").pack(side="top",fill=X)

       
m.mainloop()
